# %%
import sys, os

import pandas as pd
import numpy as np

from sklearn.svm import LinearSVC, SVC
from sklearn.model_selection import train_test_split, StratifiedKFold

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_recall_fscore_support

from sklearn.model_selection import train_test_split


import matplotlib.pyplot as plt
plt.style.use("ggplot")
import seaborn as sn

# %%
try:
    data = pd.read_csv('../dataset/new_clean_bo3.csv', encoding='utf-8-sig', converters={'p_start':eval,'p_temp':eval,'p_end':eval}, index_col=0)
except:
    sys.path.append(os.path.realpath('../'))
    data = pd.read_csv('../dataset/new_clean_bo3.csv', encoding='utf-8-sig', converters={'p_start':eval,'p_temp':eval,'p_end':eval}, index_col=0)

data = data.drop(columns=['pre_routes','freq', 'regions'])
data.reset_index(level=0, inplace=True)
print(type(data['p_start'][0]))

data.head(10)
# Out:
# <class 'tuple'>
#    level_0  index  vehicle_id            p_start  \
# 0        0      0   100000025  (106.74, 10.8014)
# 1        1     16   100000025  (106.74, 10.8014)
# 2        2     21   100000025  (106.74, 10.8014)
# 3        3     40   100000025  (106.74, 10.8014)
# 4        4     50   100000025  (106.74, 10.8014)
# 5        5     59   100000025  (106.74, 10.8014)
# 6        6    102   100000025  (106.74, 10.8014)
# 7        7    106   100000025  (106.74, 10.8014)
# 8        8    107   100000025  (106.74, 10.8014)
# 9        9    112   100000025  (106.74, 10.8014)
#
#                           p_temp                          p_end  label
# 0  (106.73899999999999, 10.8012)             (106.738, 10.8012)  False
# 1  (106.73899999999999, 10.8012)  (106.73100000000001, 10.7996)  False
# 2  (106.73899999999999, 10.8012)             (106.721, 10.7981)  False
# 3  (106.73899999999999, 10.8012)             (106.695, 10.7912)  False
# 4  (106.73899999999999, 10.8012)  (106.68799999999999, 10.7858)  False
# 5  (106.73899999999999, 10.8012)             (106.681, 10.7926)  False
# 6             (106.738, 10.8012)             (106.736, 10.8026)  False
# 7             (106.738, 10.8012)             (106.734, 10.8034)  False
# 8             (106.738, 10.8012)  (106.73200000000001, 10.8028)  False
# 9             (106.738, 10.8012)     (106.73200000000001, 10.8)  False

# %%
data[['p_start','p_temp', 'p_end', 'label']]
# Out:
#                              p_start                         p_temp  \
# 0                  (106.74, 10.8014)  (106.73899999999999, 10.8012)
# 1                  (106.74, 10.8014)  (106.73899999999999, 10.8012)
# 2                  (106.74, 10.8014)  (106.73899999999999, 10.8012)
# 3                  (106.74, 10.8014)  (106.73899999999999, 10.8012)
# 4                  (106.74, 10.8014)  (106.73899999999999, 10.8012)
# ...                              ...                            ...
# 14856  (106.682, 10.822000000000001)             (106.679, 10.8284)
# 14857             (106.682, 10.8224)              (106.68, 10.8272)
# 14858             (106.682, 10.8237)             (106.679, 10.8284)
# 14859              (106.68, 10.8272)             (106.677, 10.8429)
# 14860             (106.677, 10.8429)             (106.677, 10.8432)
#
#                                p_end  label
# 0                 (106.738, 10.8012)  False
# 1      (106.73100000000001, 10.7996)  False
# 2                 (106.721, 10.7981)  False
# 3                 (106.695, 10.7912)  False
# 4      (106.68799999999999, 10.7858)  False
# ...                              ...    ...
# 14856             (106.677, 10.8429)   True
# 14857             (106.679, 10.8515)   True
# 14858             (106.677, 10.8429)   True
# 14859             (106.677, 10.8432)   True
# 14860             (106.679, 10.8515)   True
#
# [14861 rows x 4 columns]

# %%
# data['pre_routes'] = data['pre_routes'].apply(lambda x: list(x))
data['label'] = data['label'].apply(lambda label: -1 if label == False else 1)
# data = data.sample(frac=0.4)

print("N_normal: ",len(data[data['label']==-1]))
print("N_abnormal: ",len(data[data['label']==1]))
data['label'].describe()
# Out:
# N_normal:  9401
# N_abnormal:  5460
# count    14861.000000
# mean        -0.265191
# std          0.964228
# min         -1.000000
# 25%         -1.000000
# 50%         -1.000000
# 75%          1.000000
# max          1.000000
# Name: label, dtype: float64

# %%
data['feature'] = data['p_start'] + data['p_temp'] + data['p_end']
data
# Out:
#        level_0    index  vehicle_id                        p_start  \
# 0            0        0   100000025              (106.74, 10.8014)
# 1            1       16   100000025              (106.74, 10.8014)
# 2            2       21   100000025              (106.74, 10.8014)
# 3            3       40   100000025              (106.74, 10.8014)
# 4            4       50   100000025              (106.74, 10.8014)
# ...        ...      ...         ...                            ...
# 14856    14856  7272177   100000533  (106.682, 10.822000000000001)
# 14857    14857  7272544   100000533             (106.682, 10.8224)
# 14858    14858  7272961   100000533             (106.682, 10.8237)
# 14859    14859  7274155   100000533              (106.68, 10.8272)
# 14860    14860  7276386   100000533             (106.677, 10.8429)
#
#                               p_temp                          p_end  label  \
# 0      (106.73899999999999, 10.8012)             (106.738, 10.8012)     -1
# 1      (106.73899999999999, 10.8012)  (106.73100000000001, 10.7996)     -1
# 2      (106.73899999999999, 10.8012)             (106.721, 10.7981)     -1
# 3      (106.73899999999999, 10.8012)             (106.695, 10.7912)     -1
# 4      (106.73899999999999, 10.8012)  (106.68799999999999, 10.7858)     -1
# ...                              ...                            ...    ...
# 14856             (106.679, 10.8284)             (106.677, 10.8429)      1
# 14857              (106.68, 10.8272)             (106.679, 10.8515)      1
# 14858             (106.679, 10.8284)             (106.677, 10.8429)      1
# 14859             (106.677, 10.8429)             (106.677, 10.8432)      1
# 14860             (106.677, 10.8432)             (106.679, 10.8515)      1
#
#                                                  feature
# 0      (106.74, 10.8014, 106.73899999999999, 10.8012,...
# 1      (106.74, 10.8014, 106.73899999999999, 10.8012,...
# 2      (106.74, 10.8014, 106.73899999999999, 10.8012,...
# 3      (106.74, 10.8014, 106.73899999999999, 10.8012,...
# 4      (106.74, 10.8014, 106.73899999999999, 10.8012,...
# ...                                                  ...
# 14856  (106.682, 10.822000000000001, 106.679, 10.8284...
# 14857  (106.682, 10.8224, 106.68, 10.8272, 106.679, 1...
# 14858  (106.682, 10.8237, 106.679, 10.8284, 106.677, ...
# 14859  (106.68, 10.8272, 106.677, 10.8429, 106.677, 1...
# 14860  (106.677, 10.8429, 106.677, 10.8432, 106.679, ...
#
# [14861 rows x 8 columns]

# %%
X = data['feature']
y = data['label']

# %%
# dataframe = pd.DataFrame(X_train_vec.A, columns=vectorizer.get_feature_names())
# dataframe

# %%
def clf_report(y_true, y_pred):
    print(classification_report(y_true, y_pred, target_names=['Normal','Anomaly']))

    cm = confusion_matrix(y_true,y_pred, labels=[-1,1])    
    df_cm = pd.DataFrame(cm,columns = ['Normal','Anomaly'])
    df_cm = df_cm.rename(index = {0:'Normal',1:'Anomaly'})
    sn.heatmap(df_cm, annot=True, fmt="d")
    plt.show()

    return precision_recall_fscore_support(y_true,y_pred,average='macro')

# %%
vectorizer = CountVectorizer(tokenizer=lambda doc: doc, lowercase=False)

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
clf = LinearSVC(C=5, tol=1e-5, max_iter=3000, random_state=42)

i = 1

precision_train = []
recall_train = []
f1_train = []
acc_train = []

precision_test = []
recall_test = []
f1_test = []
acc_test = []


for train_index, test_index in cv.split(X, y):
    
    print("="*50 + str(i) + "="*50)
    print()

    X_train, X_test = X.iloc[train_index], X.iloc[test_index] 
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    X_train_mat = vectorizer.fit_transform(X_train)
    X_test_mat = vectorizer.transform(X_test)
       
    clf.fit(X_train_mat,y_train)
#     clf.fit(X_train_mat)
    y_train_pred = clf.predict(X_train_mat)
    y_test_pred = clf.predict(X_test_mat)


    print("Evaluation for training")
    precision,recall,fscore,support = clf_report(y_train,y_train_pred)
    precision_train.append(precision)
    recall_train.append(recall)
    f1_train.append(fscore)
    acc_train.append(accuracy_score(y_train,y_train_pred))


    print("Evaluation for testing")
    precision,recall,fscore,support = clf_report(y_test,y_test_pred)
    precision_test.append(precision)
    recall_test.append(recall)
    f1_test.append(fscore)
    acc_test.append(accuracy_score(y_test,y_test_pred))    
    
    i+=1
    print()
    
mean_precision_train = np.mean(precision_train)
mean_recall_train = np.mean(recall_train)
mean_f1_train = np.mean(f1_train)
mean_acc_train = np.mean(acc_train)

mean_precision_test = np.mean(precision_test)
mean_recall_test = np.mean(recall_test)
mean_f1_test = np.mean(f1_test)
mean_acc_test = np.mean(acc_test)


train_perfm = [mean_precision_train, mean_recall_train, mean_f1_train, mean_acc_train]
test_perfm = [mean_precision_test, mean_recall_test, mean_f1_test, mean_acc_test]

performance = pd.DataFrame([train_perfm, test_perfm], columns = ['precision', 'recall', 'f1-score', 'accuracy'], index=['training','test'])
performance
# Out:
# ==================================================1==================================================
#
# Evaluation for training
#               precision    recall  f1-score   support
#
#       Normal       0.96      0.97      0.96      7520
#      Anomaly       0.94      0.93      0.93      4368
#
#     accuracy                           0.95     11888
#    macro avg       0.95      0.95      0.95     11888
# weighted avg       0.95      0.95      0.95     11888
# Evaluation for testing
#               precision    recall  f1-score   support
#
#       Normal       0.95      0.96      0.95      1881
#      Anomaly       0.92      0.91      0.92      1092
#
#     accuracy                           0.94      2973
#    macro avg       0.93      0.93      0.93      2973
# weighted avg       0.94      0.94      0.94      2973
# ==================================================2==================================================
#
# Evaluation for training
#               precision    recall  f1-score   support
#
#       Normal       0.96      0.97      0.97      7521
#      Anomaly       0.95      0.94      0.94      4368
#
#     accuracy                           0.96     11889
#    macro avg       0.95      0.95      0.95     11889
# weighted avg       0.96      0.96      0.96     11889
# Evaluation for testing
#               precision    recall  f1-score   support
#
#       Normal       0.94      0.93      0.94      1880
#      Anomaly       0.89      0.90      0.89      1092
#
#     accuracy                           0.92      2972
#    macro avg       0.91      0.91      0.91      2972
# weighted avg       0.92      0.92      0.92      2972
# ==================================================3==================================================
#
# Evaluation for training
#               precision    recall  f1-score   support
#
#       Normal       0.96      0.97      0.97      7521
#      Anomaly       0.94      0.94      0.94      4368
#
#     accuracy                           0.96     11889
#    macro avg       0.95      0.95      0.95     11889
# weighted avg       0.96      0.96      0.96     11889
# Evaluation for testing
#               precision    recall  f1-score   support
#
#       Normal       0.95      0.95      0.95      1880
#      Anomaly       0.91      0.91      0.91      1092
#
#     accuracy                           0.93      2972
#    macro avg       0.93      0.93      0.93      2972
# weighted avg       0.93      0.93      0.93      2972
# ==================================================4==================================================
#
# Evaluation for training
#               precision    recall  f1-score   support
#
#       Normal       0.96      0.97      0.97      7521
#      Anomaly       0.94      0.93      0.94      4368
#
#     accuracy                           0.96     11889
#    macro avg       0.95      0.95      0.95     11889
# weighted avg       0.96      0.96      0.96     11889
# Evaluation for testing
#               precision    recall  f1-score   support
#
#       Normal       0.95      0.95      0.95      1880
#      Anomaly       0.91      0.91      0.91      1092
#
#     accuracy                           0.93      2972
#    macro avg       0.93      0.93      0.93      2972
# weighted avg       0.93      0.93      0.93      2972
# ==================================================5==================================================
#
# Evaluation for training
#               precision    recall  f1-score   support
#
#       Normal       0.96      0.97      0.97      7521
#      Anomaly       0.95      0.93      0.94      4368
#
#     accuracy                           0.96     11889
#    macro avg       0.95      0.95      0.95     11889
# weighted avg       0.96      0.96      0.96     11889
# Evaluation for testing
#               precision    recall  f1-score   support
#
#       Normal       0.94      0.95      0.95      1880
#      Anomaly       0.91      0.90      0.91      1092
#
#     accuracy                           0.93      2972
#    macro avg       0.93      0.93      0.93      2972
# weighted avg       0.93      0.93      0.93      2972
#           precision    recall  f1-score  accuracy
# training   0.953102  0.950992  0.952027  0.955504
# test       0.926552  0.925542  0.926028  0.931296

# %%
X_train_mat
# Out:
# <11889x884 sparse matrix of type '<class 'numpy.int64'>'
# 	with 67462 stored elements in Compressed Sparse Row format>

# %%
X_train_mat = vectorizer.fit_transform(X_train[30:35])
dataframe = pd.DataFrame(X_train_mat.A, columns=[vectorizer.get_feature_names()])[:30]
# dataframe['X'] = X_train[30:35].tolist()

dataframe.index = X_train[30:35].to_numpy()
dataframe
# Out:
#                                                    10.7858  10.7906  10.7926   \
# (106.74, 10.8014, 106.73100000000001, 10.7996, ...        1        0        0
# (106.74, 10.8014, 106.73100000000001, 10.7996, ...        0        0        1
# (106.74, 10.8014, 106.721, 10.7981, 106.721, 10...        0        0        0
# (106.74, 10.8014, 106.721, 10.7981, 106.713, 10...        0        0        0
# (106.74, 10.8014, 106.721, 10.7981, 106.697, 10...        0        1        0
#
#                                                    10.7981  10.7983  10.7996   \
# (106.74, 10.8014, 106.73100000000001, 10.7996, ...        0        0        1
# (106.74, 10.8014, 106.73100000000001, 10.7996, ...        0        0        1
# (106.74, 10.8014, 106.721, 10.7981, 106.721, 10...        1        1        0
# (106.74, 10.8014, 106.721, 10.7981, 106.713, 10...        1        0        0
# (106.74, 10.8014, 106.721, 10.7981, 106.697, 10...        1        0        0
#
#                                                    10.8014  106.6810 106.6880  \
# (106.74, 10.8014, 106.73100000000001, 10.7996, ...        1        0        1
# (106.74, 10.8014, 106.73100000000001, 10.7996, ...        1        1        0
# (106.74, 10.8014, 106.721, 10.7981, 106.721, 10...        1        0        0
# (106.74, 10.8014, 106.721, 10.7981, 106.713, 10...        2        0        0
# (106.74, 10.8014, 106.721, 10.7981, 106.697, 10...        1        0        0
#
#                                                    106.6970 106.7130 106.7210  \
# (106.74, 10.8014, 106.73100000000001, 10.7996, ...        0        0        0
# (106.74, 10.8014, 106.73100000000001, 10.7996, ...        0        0        0
# (106.74, 10.8014, 106.721, 10.7981, 106.721, 10...        0        0        2
# (106.74, 10.8014, 106.721, 10.7981, 106.713, 10...        0        1        1
# (106.74, 10.8014, 106.721, 10.7981, 106.697, 10...        1        0        1
#
#                                                    106.7310 106.7400
# (106.74, 10.8014, 106.73100000000001, 10.7996, ...        1        1
# (106.74, 10.8014, 106.73100000000001, 10.7996, ...        1        1
# (106.74, 10.8014, 106.721, 10.7981, 106.721, 10...        0        1
# (106.74, 10.8014, 106.721, 10.7981, 106.713, 10...        0        1
# (106.74, 10.8014, 106.721, 10.7981, 106.697, 10...        0        1

# %%
X_train_mat.shape
# Out:
# (5, 14)

# %%
clf = SVC(C=5.0, kernel='rbf', tol=1e-5, max_iter=-1, random_state=42)

i = 1

precision_train = []
recall_train = []
f1_train = []
acc_train = []

precision_test = []
recall_test = []
f1_test = []
acc_test = []


for train_index, test_index in cv.split(X, y):
    
    print("="*50 + str(i) + "="*50)
    print()

    X_train, X_test = X.iloc[train_index], X.iloc[test_index] 
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    X_train_mat = vectorizer.fit_transform(X_train)
    X_test_mat = vectorizer.transform(X_test)
    
    clf.fit(X_train_mat,y_train)
#     clf.fit(X_train_mat)
    y_train_pred = clf.predict(X_train_mat)
    y_test_pred = clf.predict(X_test_mat)


    print("Evaluation for training")
    precision,recall,fscore,support = clf_report(y_train,y_train_pred)
    precision_train.append(precision)
    recall_train.append(recall)
    f1_train.append(fscore)
    acc_train.append(accuracy_score(y_train,y_train_pred))


    print("Evaluation for testing")
    precision,recall,fscore,support = clf_report(y_test,y_test_pred)
    precision_test.append(precision)
    recall_test.append(recall)
    f1_test.append(fscore)
    acc_test.append(accuracy_score(y_test,y_test_pred))    
    
    i+=1
    print()
    
mean_precision_train = np.mean(precision_train)
mean_recall_train = np.mean(recall_train)
mean_f1_train = np.mean(f1_train)
mean_acc_train = np.mean(acc_train)

mean_precision_test = np.mean(precision_test)
mean_recall_test = np.mean(recall_test)
mean_f1_test = np.mean(f1_test)
mean_acc_test = np.mean(acc_test)

train_perfm = [mean_precision_train, mean_recall_train, mean_f1_train, mean_acc_train]
test_perfm = [mean_precision_test, mean_recall_test, mean_f1_test, mean_acc_test]

performance = pd.DataFrame([train_perfm, test_perfm], columns = ['precision', 'recall', 'f1-score', 'accuracy'], index=['training','test'])
performance
# Out:
# ==================================================1==================================================
#
# Evaluation for training
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00      7520
#      Anomaly       1.00      1.00      1.00      4368
#
#     accuracy                           1.00     11888
#    macro avg       1.00      1.00      1.00     11888
# weighted avg       1.00      1.00      1.00     11888
# Evaluation for testing
#               precision    recall  f1-score   support
#
#       Normal       0.98      0.99      0.98      1881
#      Anomaly       0.98      0.97      0.97      1092
#
#     accuracy                           0.98      2973
#    macro avg       0.98      0.98      0.98      2973
# weighted avg       0.98      0.98      0.98      2973
# ==================================================2==================================================
#
# Evaluation for training
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00      7521
#      Anomaly       1.00      1.00      1.00      4368
#
#     accuracy                           1.00     11889
#    macro avg       1.00      1.00      1.00     11889
# weighted avg       1.00      1.00      1.00     11889
# Evaluation for testing
#               precision    recall  f1-score   support
#
#       Normal       0.98      0.99      0.98      1880
#      Anomaly       0.97      0.96      0.97      1092
#
#     accuracy                           0.98      2972
#    macro avg       0.98      0.97      0.98      2972
# weighted avg       0.98      0.98      0.98      2972
# ==================================================3==================================================
#
# Evaluation for training
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00      7521
#      Anomaly       1.00      1.00      1.00      4368
#
#     accuracy                           1.00     11889
#    macro avg       1.00      1.00      1.00     11889
# weighted avg       1.00      1.00      1.00     11889
# Evaluation for testing
#               precision    recall  f1-score   support
#
#       Normal       0.98      0.98      0.98      1880
#      Anomaly       0.97      0.96      0.97      1092
#
#     accuracy                           0.98      2972
#    macro avg       0.97      0.97      0.97      2972
# weighted avg       0.98      0.98      0.98      2972
# ==================================================4==================================================
#
# Evaluation for training
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00      7521
#      Anomaly       1.00      1.00      1.00      4368
#
#     accuracy                           1.00     11889
#    macro avg       1.00      1.00      1.00     11889
# weighted avg       1.00      1.00      1.00     11889
# Evaluation for testing
#               precision    recall  f1-score   support
#
#       Normal       0.98      0.98      0.98      1880
#      Anomaly       0.97      0.96      0.97      1092
#
#     accuracy                           0.97      2972
#    macro avg       0.97      0.97      0.97      2972
# weighted avg       0.97      0.97      0.97      2972
# ==================================================5==================================================
#
# Evaluation for training
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00      7521
#      Anomaly       1.00      1.00      1.00      4368
#
#     accuracy                           1.00     11889
#    macro avg       1.00      1.00      1.00     11889
# weighted avg       1.00      1.00      1.00     11889
# Evaluation for testing
#               precision    recall  f1-score   support
#
#       Normal       0.97      0.99      0.98      1880
#      Anomaly       0.97      0.95      0.96      1092
#
#     accuracy                           0.97      2972
#    macro avg       0.97      0.97      0.97      2972
# weighted avg       0.97      0.97      0.97      2972
#           precision    recall  f1-score  accuracy
# training   0.998906  0.998561  0.998733  0.998822
# test       0.975551  0.972980  0.974233  0.976112

# %%
clf = SVC(C=5.0, kernel='poly',tol=1e-5, max_iter=-1, random_state=42)

i = 1

precision_train = []
recall_train = []
f1_train = []
acc_train = []

precision_test = []
recall_test = []
f1_test = []
acc_test = []


for train_index, test_index in cv.split(X, y):
    
    print("="*50 + str(i) + "="*50)
    print()

    X_train, X_test = X.iloc[train_index], X.iloc[test_index] 
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    X_train_mat = vectorizer.fit_transform(X_train)
    X_test_mat = vectorizer.transform(X_test)
    
    clf.fit(X_train_mat,y_train)
#     clf.fit(X_train_mat)
    y_train_pred = clf.predict(X_train_mat)
    y_test_pred = clf.predict(X_test_mat)


    print("Evaluation for training")
    precision,recall,fscore,support = clf_report(y_train,y_train_pred)
    precision_train.append(precision)
    recall_train.append(recall)
    f1_train.append(fscore)
    acc_train.append(accuracy_score(y_train,y_train_pred))


    print("Evaluation for testing")
    precision,recall,fscore,support = clf_report(y_test,y_test_pred)
    precision_test.append(precision)
    recall_test.append(recall)
    f1_test.append(fscore)
    acc_test.append(accuracy_score(y_test,y_test_pred))    
    
    i+=1
    print()
    
mean_precision_train = np.mean(precision_train)
mean_recall_train = np.mean(recall_train)
mean_f1_train = np.mean(f1_train)
mean_acc_train = np.mean(acc_train)

mean_precision_test = np.mean(precision_test)
mean_recall_test = np.mean(recall_test)
mean_f1_test = np.mean(f1_test)
mean_acc_test = np.mean(acc_test)

train_perfm = [mean_precision_train, mean_recall_train, mean_f1_train, mean_acc_train]
test_perfm = [mean_precision_test, mean_recall_test, mean_f1_test, mean_acc_test]

performance = pd.DataFrame([train_perfm, test_perfm], columns = ['precision', 'recall', 'f1-score', 'accuracy'], index=['training','test'])
performance
# Out:
# ==================================================1==================================================
#
# Evaluation for training
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00      7520
#      Anomaly       1.00      1.00      1.00      4368
#
#     accuracy                           1.00     11888
#    macro avg       1.00      1.00      1.00     11888
# weighted avg       1.00      1.00      1.00     11888
# Evaluation for testing
#               precision    recall  f1-score   support
#
#       Normal       0.98      0.99      0.98      1881
#      Anomaly       0.98      0.96      0.97      1092
#
#     accuracy                           0.98      2973
#    macro avg       0.98      0.97      0.98      2973
# weighted avg       0.98      0.98      0.98      2973
# ==================================================2==================================================
#
# Evaluation for training
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00      7521
#      Anomaly       1.00      1.00      1.00      4368
#
#     accuracy                           1.00     11889
#    macro avg       1.00      1.00      1.00     11889
# weighted avg       1.00      1.00      1.00     11889
# Evaluation for testing
#               precision    recall  f1-score   support
#
#       Normal       0.97      0.98      0.98      1880
#      Anomaly       0.97      0.96      0.96      1092
#
#     accuracy                           0.97      2972
#    macro avg       0.97      0.97      0.97      2972
# weighted avg       0.97      0.97      0.97      2972
# ==================================================3==================================================
#
# Evaluation for training
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00      7521
#      Anomaly       1.00      1.00      1.00      4368
#
#     accuracy                           1.00     11889
#    macro avg       1.00      1.00      1.00     11889
# weighted avg       1.00      1.00      1.00     11889
# Evaluation for testing
#               precision    recall  f1-score   support
#
#       Normal       0.98      0.98      0.98      1880
#      Anomaly       0.97      0.96      0.96      1092
#
#     accuracy                           0.97      2972
#    macro avg       0.97      0.97      0.97      2972
# weighted avg       0.97      0.97      0.97      2972
# ==================================================4==================================================
#
# Evaluation for training
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00      7521
#      Anomaly       1.00      1.00      1.00      4368
#
#     accuracy                           1.00     11889
#    macro avg       1.00      1.00      1.00     11889
# weighted avg       1.00      1.00      1.00     11889
# Evaluation for testing
#               precision    recall  f1-score   support
#
#       Normal       0.98      0.98      0.98      1880
#      Anomaly       0.97      0.96      0.96      1092
#
#     accuracy                           0.97      2972
#    macro avg       0.97      0.97      0.97      2972
# weighted avg       0.97      0.97      0.97      2972
# ==================================================5==================================================
#
# Evaluation for training
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00      7521
#      Anomaly       1.00      1.00      1.00      4368
#
#     accuracy                           1.00     11889
#    macro avg       1.00      1.00      1.00     11889
# weighted avg       1.00      1.00      1.00     11889
# Evaluation for testing
#               precision    recall  f1-score   support
#
#       Normal       0.97      0.99      0.98      1880
#      Anomaly       0.98      0.94      0.96      1092
#
#     accuracy                           0.97      2972
#    macro avg       0.97      0.96      0.97      2972
# weighted avg       0.97      0.97      0.97      2972
#           precision    recall  f1-score  accuracy
# training   0.999270  0.999030  0.999149  0.999209
# test       0.973257  0.969769  0.971449  0.973555
